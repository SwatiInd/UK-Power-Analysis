# %% [markdown]
# #### Stack Pricing Logic
#
# ##### Stack Pricing in Power Price Forecasting
# In a stack-based price model, the idea is:
# - Estimate demand at a given time (e.g., 7 PM tomorrow).
# - Simulate the generation stack: order generators by marginal cost.
# - Dispatch generation up the stack until demand is met.
# - The last unit (marginal generator) sets the price.
#
# 👉 It mimics how market-clearing price is formed.
#
# 🧱 Basic Components of the Model
# - Demand forecast
# - Available generation units (or generation types like gas, coal, wind, etc.)
# - Marginal cost of each type
# - Generation capacity & availability (e.g. outages, wind forecast)
# - Regulations, carbon costs, fuel prices (optional but realistic)

# %%
import pandas as pd

# Sample supply stack
stack = pd.DataFrame({
    'generator': ['Wind', 'Solar', 'Nuclear', 'Gas', 'Oil'],
    'cost': [0, 5, 10, 50, 100],          # €/MWh
    'available_capacity': [20, 10, 15, 25, 10]  # MW
}).sort_values('cost')
# Simulate dispatch
stack['cumulative_capacity'] = stack['available_capacity'].cumsum()
stack
# Out:
#   generator  cost  available_capacity  cumulative_capacity
# 0      Wind     0                  20                   20
# 1     Solar     5                  10                   30
# 2   Nuclear    10                  15                   45
# 3       Gas    50                  25                   70
# 4       Oil   100                  10                   80

# %%
# Forecasted demand (e.g., for 6pm tomorrow)
demand = 55
# Find the marginal generator (first row where cumulative_capacity ≥ demand)
marginal = stack[stack['cumulative_capacity'] >= demand].iloc[0]
marginal
# Out:
# generator              Gas
# cost                    50
# available_capacity      25
# cumulative_capacity     70
# Name: 3, dtype: object

# %%
market_price = marginal['cost']
print(f"Forecasted Market Price: {market_price} £/MWh")
# Out:
# Forecasted Market Price: 50 £/MWh

# %% [markdown]
# 📈 Forecasting Use Case
# In practice, you'd:
# - Run this logic hourly or half-hourly using forecasted demand.
# - Use wind/solar forecasts to limit available capacity.
# - Account for dynamic fuel costs (e.g., gas, CO₂).
# - Layer in ML/Statistical models on top to learn patterns from historical prices + stack signals.
#
# 🧠 Example Enhancements
# - Add reserve margins, curtailments, or interconnectors.
# - Include bids/offers from real market data (e.g., from Elexon in the UK).
# - Combine with time series models (ARIMA, LSTM) or XGBoost using stack features.

# %% [markdown]
# - Look for within day demand curve, generation availability, solar, and wind forecasat
# **Demand data**
# - Explore how is the embedded wind and solar data can be integrated into the demand curve?
# - How is the forecasted peak demand to be included in half-hourly demand curve?
#
# **Supply/generation data**
# Within day latest forecasted generation availability and generation data
#
# **SNSP forecast**
# - System non-synchronous penetration: It is the percentage of how much generation or imports that will be on the system that are not synchronised with frequency
# -

# %% [markdown]
# - Forecasted prices input: (https://flex-data-docs.azurewebsites.net/enbm.forecastdapricesinputs.html)
# - Source for generation https://transparency.entsoe.eu/dashboard/show

# %%
from entsoe import EntsoePandasClient
import pandas as pd
# import matplotlib.pyplot as pltimport

# %%
# Step 1: Set up the client with your API key
client = EntsoePandasClient(api_key='YOUR_API_KEY_HERE')

# Step 2: Define parameters
country_code = 'GB'  # Great Britain
start = pd.Timestamp('2025-04-18', tz='Europe/London')
end = pd.Timestamp('2025-04-20', tz='Europe/London')  # 2 days of data

# Step 3: Query Day-Ahead Prices
prices = client.query_day_ahead_prices(country_code, start=start, end=end)

# Step 4: Display the result
print(prices.head())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 end = pd.Timestamp('2025-04-20', tz='Europe/London')  # 2 days of data
#       9 # Step 3: Query Day-Ahead Prices
# ---> 10 prices = client.query_day_ahead_prices(country_code, start=start, end=end)
#      12 # Step 4: Display the result
#      13 print(prices.head())
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\entsoe\entsoe.py:1234, in EntsoePandasClient.query_day_ahead_prices(self, country_code, start, end, resolution)
#    1232 area = lookup_area(country_code)
#    1233 # we do here extra days at start and end to fix issue 187
# -> 1234 series = self._query_day_ahead_prices(
#    1235     area,
#    1236     start=start-pd.Timedelta(days=1),
#    1237     end=end+pd.Timedelta(days=1),
#    1238     resolution=resolution
#    1239 )
#    1240 series = series.tz_convert(area.tz).sort_index()
#    1241 series = series.truncate(before=start, after=end)
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\entsoe\decorators.py:124, in year_limited.<locals>.year_wrapper(start, end, *args, **kwargs)
#     122 for _start, _end in blocks:
#     123     try:
# --> 124         frame = func(*args, start=_start, end=_end, **kwargs)
#     125         if func.__name__ != '_query_unavailability' and isinstance(frame.index, pd.DatetimeIndex):
#     126             # Due to partial matching func may return data indexed by
#     127             # timestamps outside _start and _end. In order to avoid
#    (...)    132             # If there are repeating records in a single frame (e.g. due
#     133             # to corrections) then the result will also have them.
#     134             if is_first_frame:
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\entsoe\decorators.py:69, in documents_limited.<locals>.decorator.<locals>.documents_wrapper(*args, **kwargs)
#      67 for offset in range(0, 4800 + n, n):
#      68     try:
# ---> 69         frame = func(*args, offset=offset, **kwargs)
#      70         frames.append(frame)
#      71     except NoMatchingDataError:
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\entsoe\entsoe.py:1255, in EntsoePandasClient._query_day_ahead_prices(self, area, start, end, resolution, offset)
#    1247 @year_limited
#    1248 @documents_limited(100)
#    1249 def _query_day_ahead_prices(
#    (...)   1253         resolution: Literal['60min', '30min', '15min'] = '60min',
#    1254         offset: int = 0) -> pd.Series:
# -> 1255     text = super(EntsoePandasClient, self).query_day_ahead_prices(
#    1256         area,
#    1257         start=start,
#    1258         end=end,
#    1259         offset=offset
#    1260     )
#    1261     series_all = parse_prices(text)
#    1262     series = series_all[resolution]
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\entsoe\entsoe.py:180, in EntsoeRawClient.query_day_ahead_prices(self, country_code, start, end, offset)
#     173 area = lookup_area(country_code)
#     174 params = {
#     175     'documentType': 'A44',
#     176     'in_Domain': area.code,
#     177     'out_Domain': area.code,
#     178     'offset': offset
#     179 }
# --> 180 response = self._base_request(params=params, start=start, end=end)
#     181 return response.text
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\entsoe\decorators.py:24, in retry.<locals>.retry_wrapper(*args, **kwargs)
#      22 for _ in range(self.retry_count):
#      23     try:
# ---> 24         result = func(*args, **kwargs)
#      25     except (requests.ConnectionError, gaierror) as e:
#      26         error = e
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\entsoe\entsoe.py:126, in EntsoeRawClient._base_request(self, params, start, end)
#     121             allowed = error_text.split(' ')[-30][:-2]
#     122             raise PaginationError(
#     123                 f"The API is limited to {allowed} elements per "
#     124                 f"request. This query requested for {requested} "
#     125                 f"documents and cannot be fulfilled as is.")
# --> 126     raise e
#     127 else:
#     128     # ENTSO-E has changed their server to also respond with 200 if there is no data but all parameters are valid
#     129     # this means we need to check the contents for this error even when status code 200 is returned
#     130     # to prevent parsing the full response do a text matching instead of full parsing
#     131     # also only do this when response type content is text and not for example a zip file
#     132     if response.headers.get('content-type', '') == 'application/xml':
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\entsoe\entsoe.py:100, in EntsoeRawClient._base_request(self, params, start, end)
#      97 response = self.session.get(url=URL, params=params,
#      98                             proxies=self.proxies, timeout=self.timeout)
#      99 try:
# --> 100     response.raise_for_status()
#     101 except requests.HTTPError as e:
#     102     soup = BeautifulSoup(response.text, 'html.parser')
#
# File c:\Users\swati.gupta\dl\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://web-api.tp.entsoe.eu/api?documentType=A44&in_Domain=10YGB----------A&out_Domain=10YGB----------A&offset=0&securityToken=YOUR_API_KEY_HERE&periodStart=202504162300&periodEnd=202504202300

# %%
help(EntsoePandasClient)
# Out:
# Help on class EntsoePandasClient in module entsoe.entsoe:
#
# class EntsoePandasClient(EntsoeRawClient)
#  |  EntsoePandasClient(api_key: str, session: Optional[requests.sessions.Session] = None, retry_count: int = 1, retry_delay: int = 0, proxies: Optional[Dict] = None, timeout: Optional[int] = None)
#  |
#  |  Method resolution order:
#  |      EntsoePandasClient
#  |      EntsoeRawClient
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  query_activated_balancing_energy(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, business_type: str, psr_type: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Activated Balancing Energy [17.1.E]
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      business_type: str
#  |          type of contract (see mappings.BSNTYPE)
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_activated_balancing_energy_prices(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, process_type: Optional[str] = 'A16', psr_type: Optional[str] = None, business_type: Optional[str] = None, standard_market_product: Optional[str] = None, original_market_product: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      process_type: str
#  |          A16 used if not provided
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |      business_type: str
#  |          filter query for a specific business type
#  |      standard_market_product: str
#  |      original_market_product: str
#  |          filter query for a specific product
#  |          defaults to standard product
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_aggregate_water_reservoirs_and_hydro_storage(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      offset : int
#  |          offset for querying more than 100 documents
#  |
#  |      Returns
#  |      -------
#  |      str
#  |
#  |  query_aggregated_bids(self, country_code: Union[entsoe.mappings.Area, str], process_type: str, start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code
#  |      start
#  |      end
#  |      process_type: str,
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_contracted_reserve_amount(self, country_code: Union[entsoe.mappings.Area, str], type_marketagreement_type: str, start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None, offset: int = 0) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      type_marketagreement_type : str
#  |          type of contract (see mappings.MARKETAGREEMENTTYPE)
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |      offset : int
#  |          offset for querying more than 100 documents
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_contracted_reserve_prices(self, country_code: Union[entsoe.mappings.Area, str], type_marketagreement_type: str, start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None, offset: int = 0) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area, str
#  |      type_marketagreement_type : str
#  |          type of contract (see mappings.MARKETAGREEMENTTYPE)
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |      offset : int
#  |          offset for querying more than 100 documents
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_contracted_reserve_prices_procured_capacity(self, country_code: Union[entsoe.mappings.Area, str], process_type: str, type_marketagreement_type: str, start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None, offset: int = 0) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area, str
#  |      process_type : str
#  |          type of process (see mappings.PROCESSTYPE)
#  |      type_marketagreement_type : str
#  |          type of contract (see mappings.MARKETAGREEMENTTYPE)
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |      offset : int
#  |          offset for querying more than 100 documents
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_crossborder_flows(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, **kwargs) -> pandas.core.series.Series
#  |      Note: Result will be in the timezone of the origin country
#  |
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_day_ahead_prices(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, resolution: Literal['60min', '30min', '15min'] = '60min') -> pandas.core.series.Series
#  |      Parameters
#  |      ----------
#  |      resolution: either 60min for hourly values,
#  |          30min for half-hourly values or 15min for quarterly values, throws error if type is not available
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_generation(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None, nett: bool = False, **kwargs) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter on a single psr type
#  |      nett : bool
#  |          condense generation and consumption into a nett number
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_generation_forecast(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, process_type: str = 'A01', nett: bool = False) -> Union[pandas.core.frame.DataFrame, pandas.core.series.Series]
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      process_type : str
#  |      nett : bool
#  |          condense generation and consumption into a nett number
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame | pd.Series
#  |
#  |  query_generation_import(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp) -> pandas.core.frame.DataFrame
#  |      Query the combination of both domestic generation and imports
#  |
#  |  query_generation_per_plant(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None, include_eic: bool = False, **kwargs) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter on a single psr type
#  |      include_eic: bool
#  |          if True also include the eic code in the output
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_imbalance_prices(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_imbalance_volumes(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_import(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp) -> pandas.core.frame.DataFrame
#  |      Utility function wrapper for query_sum_physical_crossborder for backwards compatibility reason
#  |
#  |  query_installed_generation_capacity(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_installed_generation_capacity_per_unit(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter query for a specific psr type
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_intraday_offered_capacity(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, implicit: bool = True, **kwargs) -> pandas.core.series.Series
#  |      Note: Result will be in the timezone of the origin country  --> to check
#  |
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      implicit: bool (True = implicit - default for most borders. False = explicit - for instance BE-GB)
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_intraday_wind_and_solar_forecast(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |
#  |  query_load(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_load_and_forecast(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp) -> pandas.core.frame.DataFrame
#  |      utility function to combina query realised load and forecasted day ahead load.
#  |      this mimics the html view on the page Total Load - Day Ahead / Actual
#  |
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_load_forecast(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, process_type: str = 'A01') -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      process_type : str
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_net_position(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, dayahead: bool = True, resolution: Literal['60min', '30min', '15min'] = '60min') -> pandas.core.series.Series
#  |      Parameters
#  |      ----------
#  |      country_code
#  |      start
#  |      end
#  |
#  |      Returns
#  |      -------
#  |
#  |  query_net_transfer_capacity_dayahead(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, **kwargs) -> pandas.core.series.Series
#  |      Note: Result will be in the timezone of the origin country
#  |
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_net_transfer_capacity_monthahead(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, **kwargs) -> pandas.core.series.Series
#  |      Note: Result will be in the timezone of the origin country
#  |
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_net_transfer_capacity_weekahead(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, **kwargs) -> pandas.core.series.Series
#  |      Note: Result will be in the timezone of the origin country
#  |
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_net_transfer_capacity_yearahead(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, **kwargs) -> pandas.core.series.Series
#  |      Note: Result will be in the timezone of the origin country
#  |
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_offered_capacity(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], contract_marketagreement_type: str, start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, implicit: bool = True, offset: int = 0, **kwargs) -> pandas.core.series.Series
#  |      Allocated result documents, for OC evolution see query_intraday_offered_capacity
#  |      Note: Result will be in the timezone of the origin country  --> to check
#  |
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      contract_marketagreement_type : str
#  |          type of contract (see mappings.MARKETAGREEMENTTYPE)
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      implicit: bool (True = implicit - default for most borders. False = explicit - for instance BE-GB)
#  |      offset: int
#  |          offset for querying more than 100 documents
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_physical_crossborder_allborders(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, export: bool, per_hour: bool = False) -> pandas.core.frame.DataFrame
#  |      Adds together all physical cross-border flows to a country for a given direction
#  |      The neighbours of a country are given by the NEIGHBOURS mapping
#  |
#  |      if export is True then all export flows are returned, if False then all import flows are returned
#  |      some borders have more then once data points per hour. Set per_hour=True if you always want hourly data,
#  |      it will then thake the mean
#  |
#  |  query_procured_balancing_capacity(self, country_code: Union[entsoe.mappings.Area, str], process_type: str, start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, type_marketagreement_type: Optional[str] = None) -> bytes
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      process_type : str
#  |          A51 ... aFRR; A47 ... mFRR
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      type_marketagreement_type : str
#  |          type of contract (see mappings.MARKETAGREEMENTTYPE)
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_scheduled_exchanges(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, dayahead: bool = False, **kwargs) -> pandas.core.series.Series
#  |      Note: Result will be in the timezone of the origin country
#  |
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      dayahead : bool
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.Series
#  |
#  |  query_unavailability_of_generation_units(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, docstatus: Optional[str] = None, periodstartupdate: Optional[pandas._libs.tslibs.timestamps.Timestamp] = None, periodendupdate: Optional[pandas._libs.tslibs.timestamps.Timestamp] = None, mRID=None) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      docstatus : str, optional
#  |      periodstartupdate : pd.Timestamp, optional
#  |      periodendupdate : pd.Timestamp, optional
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_unavailability_of_offshore_grid(self, area_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp) -> pandas.core.frame.DataFrame
#  |
#  |  query_unavailability_of_production_units(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, docstatus: Optional[str] = None, periodstartupdate: Optional[pandas._libs.tslibs.timestamps.Timestamp] = None, periodendupdate: Optional[pandas._libs.tslibs.timestamps.Timestamp] = None, mRID: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      docstatus : str, optional
#  |      periodstartupdate : pd.Timestamp, optional
#  |      periodendupdate : pd.Timestamp, optional
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_unavailability_transmission(self, country_code_from: Union[entsoe.mappings.Area, str], country_code_to: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, docstatus: Optional[str] = None, periodstartupdate: Optional[pandas._libs.tslibs.timestamps.Timestamp] = None, periodendupdate: Optional[pandas._libs.tslibs.timestamps.Timestamp] = None, offset: int = 0, **kwargs) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code_from : Area|str
#  |      country_code_to : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      docstatus : str, optional
#  |      periodstartupdate : pd.Timestamp, optional
#  |      periodendupdate : pd.Timestamp, optional
#  |      offset : int
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_wind_and_solar_forecast(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, psr_type: Optional[str] = None, process_type: str = 'A01', **kwargs) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |      psr_type : str
#  |          filter on a single psr type
#  |      process_type : str
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  query_withdrawn_unavailability_of_generation_units(self, country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp) -> pandas.core.frame.DataFrame
#  |      Parameters
#  |      ----------
#  |      country_code : Area|str
#  |      start : pd.Timestamp
#  |      end : pd.Timestamp
#  |
#  |      Returns
#  |      -------
#  |      pd.DataFrame
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from EntsoeRawClient:
#  |
#  |  __init__(self, api_key: str, session: Optional[requests.sessions.Session] = None, retry_count: int = 1, retry_delay: int = 0, proxies: Optional[Dict] = None, timeout: Optional[int] = None)
#  |      Parameters
#  |      ----------
#  |      api_key : str
#  |      session : requests.Session
#  |      retry_count : int
#  |          number of times to retry the call if the connection fails
#  |      retry_delay: int
#  |          amount of seconds to wait between retries
#  |      proxies : dict
#  |          requests proxies
#  |      timeout : int
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from EntsoeRawClient:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
